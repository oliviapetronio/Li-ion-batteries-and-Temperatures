# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read in files from excel
nmc05 = pd.read_excel('NMC_k1_1C_05degC.xlsx')
nmc25 = pd.read_excel('NMC_k1_1C_25degC.xlsx')
nmc35 = pd.read_excel('NMC_k1_1C_35degC.xlsx')

# %%
# Remove variables not being studies, date_time, test_time(s), step_time(s), step_index 

nmc05 = nmc05.drop(["Date_Time","Test_Time(s)", "Step_Time(s)", "Step_Index"], axis = 1)
nmc25 = nmc25.drop(["Date_Time","Test_Time(s)", "Step_Time(s)", "Step_Index"], axis = 1)
nmc35 = nmc35.drop(["Date_Time","Test_Time(s)", "Step_Time(s)", "Step_Index"], axis = 1)

# %% [markdown]
# ## Overall data

# %%
print('Summary statistics for nca05:', nmc05.describe())
print('\n')
print('Null values: \n', nmc05.isna().sum())
# Out:
# Summary statistics for nca05:          Voltage(V)    Current(A)  Surface_Temp(degC)
# count  26962.000000  26962.000000        26962.000000
# mean       3.822418      0.046446            9.533182
# std        0.416990      1.930447            2.641445
# min        2.499979     -5.000461            7.835439
# 25%        3.530626      0.000000            8.300358
# 50%        3.978305      0.294323            8.551987
# 75%        4.199897      1.455247            8.923851
# max        4.200254      1.457806           20.272860
#
#
# Null values:
#  Voltage(V)            0
# Current(A)            0
# Surface_Temp(degC)    0
# dtype: int64

# %%
print('Summary statistics for nca05:', nmc25.describe())
print('\n')
print('Null values: \n', nmc25.isna().sum())
# Out:
# Summary statistics for nca05:          Voltage(V)    Current(A)  Surface_Temp(degC)
# count  28669.000000  28669.000000        28669.000000
# mean       3.671016      0.020670           26.082421
# std        0.497959      1.967906            1.240937
# min        2.499981     -5.000386           25.000313
# 25%        3.056888      0.000000           25.290737
# 50%        3.762293      0.055448           25.741610
# 75%        4.189954      1.625170           26.008080
# max        4.200284      1.627902           31.169395
#
#
# Null values:
#  Voltage(V)            0
# Current(A)            0
# Surface_Temp(degC)    0
# dtype: int64

# %%
print('Summary statistics for nca05:', nmc35.describe())
print('\n')
print('Null values: \n', nmc35.isna().sum())
# Out:
# Summary statistics for nca05:          Voltage(V)    Current(A)  Surface_Temp(degC)
# count  26107.000000  26107.000000        26107.000000
# mean       3.765155      0.028234           36.120790
# std        0.448428      2.027646            1.507021
# min        2.499990     -5.000475           35.071144
# 25%        3.439318      0.000000           35.203430
# 50%        3.873964      0.374099           35.702393
# 75%        4.191692      1.455220           35.955700
# max        4.200261      1.457472           41.918869
#
#
# Null values:
#  Voltage(V)            0
# Current(A)            0
# Surface_Temp(degC)    0
# dtype: int64

# %% [markdown]
# ## Get general overview through plotting

# %%
#First will be voltage
nmc05.hist(column = 'Voltage(V)', bins = 10)
plt.title('nmc05')
plt.xlabel('Voltage')
plt.show()

nmc25.hist(column = 'Voltage(V)', bins = 10)
plt.title('nmc25')
plt.xlabel('Voltage')
plt.show()

nmc35.hist(column = 'Voltage(V)', bins = 10)
plt.title('nmc35')
plt.xlabel('Voltage')
plt.show()

# %%
sns.violinplot(data=nmc05, x = 'Voltage(V)')
# Out:
# <Axes: xlabel='Voltage(V)'>

# %%
sns.violinplot(data=nmc25, x = 'Voltage(V)')
# Out:
# <Axes: xlabel='Voltage(V)'>

# %%
sns.violinplot(data=nmc35, x = 'Voltage(V)')
# Out:
# <Axes: xlabel='Voltage(V)'>

# %%
# The second feature is current measured in ampere

nmc05.hist(column = 'Current(A)', bins = 10)
plt.title('nmc05')
plt.xlabel('Voltage')
plt.show()

nmc25.hist(column = 'Current(A)', bins = 10)
plt.title('nmc25')
plt.xlabel('Voltage')
plt.show()

nmc35.hist(column = 'Current(A)', bins = 10)
plt.title('nmc35')
plt.xlabel('Voltage')
plt.show()

# %%
sns.violinplot(data=nmc05, x = 'Current(A)')
# Out:
# <Axes: xlabel='Current(A)'>

# %%
sns.violinplot(data=nmc25, x = 'Current(A)')
# Out:
# <Axes: xlabel='Current(A)'>

# %%
sns.violinplot(data=nmc35, x = 'Current(A)')
# Out:
# <Axes: xlabel='Current(A)'>

# %%
# The second feature histograms, surface temperature, measured in celsius 
nmc05.hist(column = 'Surface_Temp(degC)', bins = 10)
plt.title('nmc05')
plt.xlabel('Surface_Temp(degC)')
plt.show()

nmc25.hist(column = 'Surface_Temp(degC)', bins = 10)
plt.title('nmc25')
plt.xlabel('Surface_Temp(degC)')
plt.show()

nmc35.hist(column = 'Surface_Temp(degC)', bins = 10)
plt.title('nmc35')
plt.xlabel('Surface_Temp(degC)')
plt.show()

# %%
sns.violinplot(data=nmc05, x = 'Surface_Temp(degC)')
# Out:
# <Axes: xlabel='Surface_Temp(degC)'>

# %%
sns.violinplot(data=nmc25, x = 'Surface_Temp(degC)')
# Out:
# <Axes: xlabel='Surface_Temp(degC)'>

# %%
sns.violinplot(data=nmc35, x = 'Surface_Temp(degC)')
# Out:
# <Axes: xlabel='Surface_Temp(degC)'>

# %%
# Get correlations of the variables studying for nmc battery type

corrMatrixNmc05 = nmc05.corr()
plt.figure(figsize=(5,5))
sns.heatmap(corrMatrixNmc05, annot=True, cmap='coolwarm', fmt = '.2f', linewidths = .5)

plt.title('Correlation Heatmap for NMC deg: 05')
plt.show()


corrMatrixNmc25 = nmc25.corr()
plt.figure(figsize=(5,5))
sns.heatmap(corrMatrixNmc25, annot=True, cmap='coolwarm', fmt = '.2f', linewidths = .5)

plt.title('Correlation Heatmap for NMC deg: 25')
plt.show()

corrMatrixNmc35 = nmc35.corr()
plt.figure(figsize=(5,5))
sns.heatmap(corrMatrixNmc35, annot=True, cmap='coolwarm', fmt = '.2f', linewidths = .5)

plt.title('Correlation Heatmap for NMC deg: 35')
plt.show()
